# %%
import pandas as pd #for handling csv and csv contents
from rdflib import Graph, Literal, RDF,RDFS, URIRef, Namespace #basic RDF handling
from rdflib.namespace import FOAF , XSD #most common namespaces
import urllib.parse #for parsing strings to URI's

import math
import numpy as np

import io
import pydotplus
from IPython.display import display, Image
from rdflib.tools.rdf2dot import rdf2dot

# %%
def visualize(g):
    stream = io.StringIO()
    rdf2dot(g, stream, opts = {display})
    dg = pydotplus.graph_from_dot_data(stream.getvalue())
    png = dg.create_png()
    display(Image(png))

# %%
uri = Namespace('http://exampleDb.org/')

# %% [markdown]
# # tbox

# %%
#classes
Paper = uri['Paper']

#subclasses of paper
poster = uri['poster']
shortPaper = uri['shortPaper']
fullPaper = uri['fullPaper']
demoPaper = uri['demoPaper']
#class 
Publication = uri['Publication']
review = uri['review']

#class
Person = uri['Person']

#subclasses of person
reviewer = uri['reviewer']
chair = uri['chair']
editor = uri['editor']
author = uri['author']

#class 
area = uri['area']

#subclasses of area
ml = uri['ml']
db = uri['db']
nlp = uri['nlp']

#class 
venue = uri['venue']

#subclasses of venue
journal = uri['journal']
conference = uri['conference']

##subclasses of conference
workshops = uri['workshops']
symposiums = uri['symposiums']
expertGrou = uri['expertGroups']
regularConferences = uri['regularConferences']

#properties 

#paper acceptedfor publication 
accepted = uri['acceptedfor']
#relatedArea
relatedto = uri['relatedto']
#paper submittedIn
submittedIn = uri['submittedIn']
#author wrote paper
wrote = uri['wrote']
#reviewer Submitted review
R_submitted = uri['submitted']

# %%
g = Graph()

# %%
#class
g.add((Paper,RDF.type, RDFS.Class))
g.add((Publication,RDF.type, RDFS.Class))
g.add((review,RDF.type, RDFS.Class))
g.add((Person,RDF.type, RDFS.Class))
g.add((area,RDF.type, RDFS.Class))
g.add((venue,RDF.type, RDFS.Class))

#subclasses 
g.add((poster, RDFS.subClassOf, Paper))
g.add((shortPaper, RDFS.subClassOf, Paper))
g.add((fullPaper, RDFS.subClassOf, Paper))
g.add((demoPaper, RDFS.subClassOf, Paper))

g.add((reviewer, RDFS.subClassOf, Person))
g.add((chair, RDFS.subClassOf, Person))
g.add((editor, RDFS.subClassOf, Person))
g.add((author, RDFS.subClassOf, Person))

g.add((ml, RDFS.subClassOf, area))
g.add((db, RDFS.subClassOf, area))
g.add((nlp, RDFS.subClassOf, area))

g.add((conference, RDFS.subClassOf, venue))
g.add((journal, RDFS.subClassOf, venue))

g.add((workshops, RDFS.subClassOf, conference))
g.add((symposiums, RDFS.subClassOf, conference))
g.add((expertGrou, RDFS.subClassOf, conference))
g.add((regularConferences, RDFS.subClassOf, conference))

#properties
g.add((accepted,RDF.type, RDF.Property))
g.add((accepted,RDFS.domain,Paper))
g.add((accepted,RDFS.range,Publication))
g.add((Paper,accepted,Publication))

g.add((relatedto,RDF.type, RDF.Property))
g.add((relatedto,RDFS.domain,Paper))
g.add((relatedto,RDFS.range,area))
g.add((Paper,relatedto,area))

g.add((submittedIn,RDF.type, RDF.Property))
g.add((submittedIn,RDFS.domain,Paper))
g.add((submittedIn,RDFS.range,venue))
g.add((Paper,submittedIn,venue))

g.add((wrote,RDF.type, RDF.Property))
g.add((wrote,RDFS.domain,author))
g.add((wrote,RDFS.range,Paper))
g.add((author,wrote,Paper))

g.add((R_submitted,RDF.type, RDF.Property))
g.add((R_submitted,RDFS.domain,reviewer))
g.add((R_submitted,RDFS.range,review))
g.add((reviewer,R_submitted,review))

# g.add((accepted,RDF.type, RDF.Property))
# g.add((accepted,RDFS.domain,Paper))
# g.add((accepted,RDFS.range,Publication))
# Out:
# <Graph identifier=N2d451727c682401896789b3958706c32 (<class 'rdflib.graph.Graph'>)>

# %%
visualize(g)
# Out:
# (dot.exe:27232): Pango-WARNING **: couldn't load font "DejaVu Sans Bold Not-Rotated 14", falling back to "Sans Bold Not-Rotated 14", expect ugly output.
#
# (dot.exe:27232): Pango-WARNING **: couldn't load font "DejaVu Sans Not-Rotated 10", falling back to "Sans Not-Rotated 10", expect ugly output.

# %%
# Save the results to disk
g.serialize('ptbox.ttl',format='turtle')
# Out:
# <Graph identifier=N2d451727c682401896789b3958706c32 (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# # Abox

# %% [markdown]
# ## Person

# %%
url='kaggle_data_processed/authors.csv'
df=pd.read_csv(url,sep=",")
# df # uncomment to check for contents

# %%
 df.shape
# Out:
# (2172, 2)

# %%
sixty = math.ceil(df.shape[0]*.6)
eighty = math.ceil(df.shape[0]*.8)
nine = math.ceil(df.shape[0]*.9)
auth_sixty = df.iloc[:sixty,:]
review_twenty = df.iloc[sixty:eighty,:]
chair_ten = df.iloc[eighty:nine,:]
editor_ten = df.iloc[nine:,:]

# %%
for index, row in auth_sixty.iterrows():
    g.add((author+str(row['ID']),RDF.type,author) )
    g.add((author+str(row['ID']),FOAF.name, Literal(row['name'], datatype=XSD.string)) )
    
for index, row in review_twenty.iterrows():
    g.add((reviewer+str(row['ID']),RDF.type,reviewer) )
    g.add((reviewer+str(row['ID']),FOAF.name, Literal(row['name'], datatype=XSD.string)) )

for index, row in chair_ten.iterrows():
    g.add((chair+str(row['ID']),RDF.type,chair) )
    g.add((chair+str(row['ID']),FOAF.name, Literal(row['name'], datatype=XSD.string)) )

for index, row in editor_ten.iterrows():
    g.add((editor+str(row['ID']),RDF.type,editor) )
    g.add((editor+str(row['ID']),FOAF.name, Literal(row['name'], datatype=XSD.string)) )
    
#     #g.add((URIRef('http://example.org/people/Country'+row['Country'].replace(" ", "_")),RDF.type,Country) )
#     g.add((URIRef('http://example.org/people/Country'+row['Country'].replace(" ", "_")),FOAF.name, Literal(row['Country'], datatype=XSD.string)))
    
#     g.add((URIRef('http://example.org/people/Person'+row['Name']),lives_in,URIRef('http://example.org/people/Country'+row['Country'].replace(" ", "_"))))

# %% [markdown]
# # Paper
# ## author wrote papers
# 60%

# %%
written_articles = pd.read_csv('kaggle_data_processed/author_written_article.csv')
written_articles
# Out:
#          author_ID  article_ID
# 0     5.721820e+10           1
# 1     7.004904e+09           1
# 2     7.005513e+09           1
# 3     6.508306e+09           2
# 4     9.277159e+09           2
# ...            ...         ...
# 3936  7.401698e+09         880
# 3937  8.702836e+09         880
# 3938  7.005306e+09         880
# 3939  7.102555e+09         880
# 3940  3.585454e+10         880
#
# [3941 rows x 2 columns]

# %%
auth_art = pd.merge(auth_sixty, written_articles, how='left', left_on='ID', right_on='author_ID')
#auth_art = np.where((df['ID'] == written_articles['author_ID']), written_articles)

# %%
auth_art.drop(['author_ID'],axis= 1,inplace=True)

# %%
auth_art
# Out:
#                ID           name  article_ID
# 0     57218202833      Gautam A.           1
# 1      7004904337  Crandall J.W.           1
# 2      7004904337  Crandall J.W.         156
# 3      7004904337  Crandall J.W.         298
# 4      7004904337  Crandall J.W.         626
# ...           ...            ...         ...
# 2874  56701050600  Reynolds P.R.         799
# 2875  57203184524      Cramer J.         444
# 2876  57201465968       Adams D.         444
# 2877  56248395300       Brown T.         444
# 2878  57203180153       Misha R.         444
#
# [2879 rows x 3 columns]

# %%
Name_articles = pd.read_csv('kaggle_data_processed/articles.csv')

# %%
Name_articles
# Out:
#       ID                                              title     volume  \
# 0      1  Self-assessment of Proficiency of Intelligent ...  1210 AISC
# 1      2  Bridging theory to practice: Feedforward and c...   695 LNEE
# 2      3  Development of sediment management guidelines ...        146
# 3      4  Structural design space exploration using prin...         20
# 4      5  Religion-focused dating apps: A Q methodology ...         55
# ..   ...                                                ...        ...
# 875  876  Formability of magnesium alloy AZ31B from room...    Part F8
# 876  877  A summary of data-aided equalizer experiments ...        NaN
# 877  878  Joining Dissimilar Material Using Friction Sti...        NaN
# 878  879  A minimal realization technique for the dynami...          4
# 879  880               Dryland agriculture in north america        NaN
#
#                                     DOI
# 0          10.1007/978-3-030-51758-8_15
# 1           10.1007/978-3-030-58653-9_3
# 2    10.1061/(ASCE)HY.1943-7900.0001822
# 3                     10.1115/1.4047428
# 4            10.1016/j.tele.2020.101448
# ..                                  ...
# 875        10.1007/978-3-319-52392-7_91
# 876                                 NaN
# 877        10.1007/978-3-319-52383-5_16
# 878           10.1109/TCNS.2015.2498468
# 879        10.1007/978-3-319-47928-6_15
#
# [880 rows x 4 columns]

# %%
NArt = pd.merge(auth_art, Name_articles, how='left', left_on='article_ID', right_on='ID')

# %%
NArt.drop(['ID_y','volume','DOI'],axis=1,inplace =True)

# %%
NArt
# Out:
#              ID_x           name  article_ID  \
# 0     57218202833      Gautam A.           1
# 1      7004904337  Crandall J.W.           1
# 2      7004904337  Crandall J.W.         156
# 3      7004904337  Crandall J.W.         298
# 4      7004904337  Crandall J.W.         626
# ...           ...            ...         ...
# 2874  56701050600  Reynolds P.R.         799
# 2875  57203184524      Cramer J.         444
# 2876  57201465968       Adams D.         444
# 2877  56248395300       Brown T.         444
# 2878  57203180153       Misha R.         444
#
#                                                   title
# 0     Self-assessment of Proficiency of Intelligent ...
# 1     Self-assessment of Proficiency of Intelligent ...
# 2     Moderating operator influence in human-swarm s...
# 3     Cooperating in long-term relationships with ti...
# 4     Information design in crowdfunding under thres...
# ...                                                 ...
# 2874  Re-epithelialization of whole porcine kidneys ...
# 2875  Effect of strain path on forming limits and re...
# 2876  Effect of strain path on forming limits and re...
# 2877  Effect of strain path on forming limits and re...
# 2878  Effect of strain path on forming limits and re...
#
# [2879 rows x 4 columns]

# %%
NArt['Papertype'] = ''

# %%
# divide paper into subclasses type
tf = math.ceil(NArt.shape[0]*.25)
NArt['Papertype'] = ''
NArt['Papertype'].iloc[:tf] = 'fullPaper'
NArt['Papertype'].iloc[tf:2*tf] = 'demoPaper'
NArt['Papertype'].iloc[2*tf:3*tf] = 'shortPaper'
NArt['Papertype'].iloc[3*tf:] = 'Poster'
# Out:
# <ipython-input-141-708dbe82bc38>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NArt['Papertype'].iloc[:tf] = 'fullPaper'
# <ipython-input-141-708dbe82bc38>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NArt['Papertype'].iloc[tf:2*tf] = 'demoPaper'
# <ipython-input-141-708dbe82bc38>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NArt['Papertype'].iloc[2*tf:3*tf] = 'shortPaper'
# <ipython-input-141-708dbe82bc38>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NArt['Papertype'].iloc[3*tf:] = 'Poster'

# %%
NArt[NArt['Papertype'] == 'fullPaper']
# Out:
#             ID_x           name  article_ID  \
# 0    57218202833      Gautam A.           1
# 1     7004904337  Crandall J.W.           1
# 2     7004904337  Crandall J.W.         156
# 3     7004904337  Crandall J.W.         298
# 4     7004904337  Crandall J.W.         626
# ..           ...            ...         ...
# 715  36987999600     Afran M.S.         160
# 716  36987999600     Afran M.S.         615
# 717  36987999600     Afran M.S.         842
# 718  36987999600     Afran M.S.         877
# 719   7003868048      Saquib M.          39
#
#                                                  title  Papertype
# 0    Self-assessment of Proficiency of Intelligent ...  fullPaper
# 1    Self-assessment of Proficiency of Intelligent ...  fullPaper
# 2    Moderating operator influence in human-swarm s...  fullPaper
# 3    Cooperating in long-term relationships with ti...  fullPaper
# 4    Information design in crowdfunding under thres...  fullPaper
# ..                                                 ...        ...
# 715  On Sparse Channel Estimation in Aeronautical T...  fullPaper
# 716  Cfo estimation by exploiting channel sparsity ...  fullPaper
# 717  Sparse MMSE equalizer for GTR-STBC in aeronaut...  fullPaper
# 718  A summary of data-aided equalizer experiments ...  fullPaper
# 719  On the effects of channel sparsity on joint es...  fullPaper
#
# [720 rows x 5 columns]

# %%
# author wrote article
for index, row in fppr.iterrows():
    g.add((fullPaper+str(row['article_ID']),RDF.type,fullPaper) )
    g.add((fullPaper+str(row['article_ID']),FOAF.name, Literal(row['title'], datatype=XSD.string)) )
    g.add((author+str(row['ID_x']),wrote,fullPaper+str(row['article_ID'])))
    

for index, row in dppr.iterrows():
    g.add((demoPaper+str(row['article_ID']),RDF.type,demoPaper) )
    g.add((demoPaper+str(row['article_ID']),FOAF.name, Literal(row['title'], datatype=XSD.string)) )
    g.add((author+str(row['ID_x']),wrote,demoPaper+str(row['article_ID'])))

for index, row in sppr.iterrows():
    g.add((shortPaper+str(row['article_ID']),RDF.type,shortPaper) )
    g.add((shortPaper+str(row['article_ID']),FOAF.name, Literal(row['title'], datatype=XSD.string)) )
    g.add((author+str(row['ID_x']),wrote,shortPaper+str(row['article_ID'])))

for index, row in ppr.iterrows():
    g.add((poster+str(row['article_ID']),RDF.type,poster) )
    g.add((poster+str(row['article_ID']),FOAF.name, Literal(row['title'], datatype=XSD.string)) )
    g.add((author+str(row['ID_x']),wrote,poster+str(row['article_ID'])))

# %% [markdown]
# # published

# %%
pubName = pd.read_csv('kaggle_data_processed/publications.csv')

# %%
pubName
# Out:
#       ID                                               name              Type
# 0      1      Advances in Intelligent Systems and Computing  Conference Paper
# 1      2            Lecture Notes in Electrical Engineering  Conference Paper
# 2      3                   Journal of Hydraulic Engineering           Journal
# 3      4  Journal of Computing and Information Science i...           Journal
# 4      5                         Telematics and Informatics  Conference Paper
# ..   ...                                                ...               ...
# 399  400                          CAD Computer Aided Design  Conference Paper
# 400  401  International Symposium on Advances in Computa...  Conference Paper
# 401  402  AIAA SPACE and Astronautics Forum and Expositi...  Conference Paper
# 402  403    IEEE Transactions on Control of Network Systems  Conference Paper
# 403  404                 Innovations in Dryland Agriculture  Conference Paper
#
# [404 rows x 3 columns]

# %%
for index,row in pubName.iterrows():
    g.add((Publication+str(row['ID']),RDF.type,Publication) )
    g.add((Publication+str(row['ID']),FOAF.name, Literal(row['name'], datatype=XSD.string)))

# %% [markdown]
# ### published by

# %%
publishedIn = pd.read_csv('kaggle_data_processed/article_published_by.csv')

# %%
publishedIn
# Out:
#       article_ID  publisher_ID  year
# 0              1           433  2020
# 1              1           435  2019
# 2              1           780  2019
# 3              1           612  2020
# 4              2           378  2020
# ...          ...           ...   ...
# 3534         879           141  2016
# 3535         879           475  2015
# 3536         880           492  2016
# 3537         880           300  2017
# 3538         880           818  2017
#
# [3539 rows x 3 columns]

# %%
publ = pd.merge(NArt, publishedIn, how='left', on='article_ID')

# %%
publ = publ[publ['publisher_ID']<=404]

# %%
publ
# Out:
#               ID_x           name  article_ID  \
# 13      7004904337  Crandall J.W.         298
# 17      7004904337  Crandall J.W.         626
# 19      7004904337  Crandall J.W.         626
# 30      7005513246  Goodrich M.A.         157
# 31      7005513246  Goodrich M.A.         175
# ...            ...            ...         ...
# 11511  56701050600  Reynolds P.R.         443
# 11512  56701050600  Reynolds P.R.         443
# 11515  56701050600  Reynolds P.R.         443
# 11516  56701050600  Reynolds P.R.         799
# 11517  56701050600  Reynolds P.R.         799
#
#                                                    title  Papertype  \
# 13     Cooperating in long-term relationships with ti...  fullPaper
# 17     Information design in crowdfunding under thres...  fullPaper
# 19     Information design in crowdfunding under thres...  fullPaper
# 30     Intent-based robotic path-replanning: When to ...  fullPaper
# 31     Transparency: Transitioning From Human–Machine...  fullPaper
# ...                                                  ...        ...
# 11511  Corrigendum: Efficient decellularization of wh...     Poster
# 11512  Corrigendum: Efficient decellularization of wh...     Poster
# 11515  Corrigendum: Efficient decellularization of wh...     Poster
# 11516  Re-epithelialization of whole porcine kidneys ...     Poster
# 11517  Re-epithelialization of whole porcine kidneys ...     Poster
#
#        publisher_ID  year
# 13              247  2017
# 17              313  2017
# 19              253  2018
# 30              390  2019
# 31               18  2017
# ...             ...   ...
# 11511            16  2017
# 11512           347  2017
# 11515           273  2017
# 11516           182  2016
# 11517           350  2017
#
# [5320 rows x 7 columns]

# %%
NPub = pd.merge(publ, pubName, how='left', left_on='publisher_ID', right_on='ID')

# %%
NPub
# Out:
#              ID_x         name_x  article_ID  \
# 0      7004904337  Crandall J.W.         298
# 1      7004904337  Crandall J.W.         626
# 2      7004904337  Crandall J.W.         626
# 3      7005513246  Goodrich M.A.         157
# 4      7005513246  Goodrich M.A.         175
# ...           ...            ...         ...
# 5315  56701050600  Reynolds P.R.         443
# 5316  56701050600  Reynolds P.R.         443
# 5317  56701050600  Reynolds P.R.         443
# 5318  56701050600  Reynolds P.R.         799
# 5319  56701050600  Reynolds P.R.         799
#
#                                                   title  Papertype  \
# 0     Cooperating in long-term relationships with ti...  fullPaper
# 1     Information design in crowdfunding under thres...  fullPaper
# 2     Information design in crowdfunding under thres...  fullPaper
# 3     Intent-based robotic path-replanning: When to ...  fullPaper
# 4     Transparency: Transitioning From Human–Machine...  fullPaper
# ...                                                 ...        ...
# 5315  Corrigendum: Efficient decellularization of wh...     Poster
# 5316  Corrigendum: Efficient decellularization of wh...     Poster
# 5317  Corrigendum: Efficient decellularization of wh...     Poster
# 5318  Re-epithelialization of whole porcine kidneys ...     Poster
# 5319  Re-epithelialization of whole porcine kidneys ...     Poster
#
#       publisher_ID  year   ID  \
# 0              247  2017  247
# 1              313  2017  313
# 2              253  2018  253
# 3              390  2019  390
# 4               18  2017   18
# ...            ...   ...  ...
# 5315            16  2017   16
# 5316           347  2017  347
# 5317           273  2017  273
# 5318           182  2016  182
# 5319           350  2017  350
#
#                                                  name_y              Type
# 0          Theoretical and Computational Fluid Dynamics  Conference Paper
# 1     2018 Aviation Technology, Integration, and Ope...  Conference Paper
# 2     2018 IEEE 3rd International Verification and S...  Conference Paper
# 3     IGLC 2017 - Proceedings of the 25th Annual Con...  Conference Paper
# 4                           Applied Thermal Engineering  Conference Paper
# ...                                                 ...               ...
# 5315               Journal of Nondestructive Evaluation           Journal
# 5316  Journal of Traffic and Transportation Engineer...           Journal
# 5317        Handbook of Thermal Science and Engineering  Conference Paper
# 5318  Proceedings of the IEEE Conference on Decision...  Conference Paper
# 5319                    Journal of Technology Education           Journal
#
# [5320 rows x 10 columns]

# %%
NPub.drop(['ID'],axis=1,inplace =True)

# %% [markdown]
# ## paper related to area

# %%
g.add((ml,FOAF.name, Literal('Machine_learning', datatype=XSD.string)))
g.add((db,FOAF.name, Literal('Databases', datatype=XSD.string)))
g.add((nlp,FOAF.name, Literal('Natural_language_Processing', datatype=XSD.string)))
# Out:
# <Graph identifier=N2d451727c682401896789b3958706c32 (<class 'rdflib.graph.Graph'>)>

# %%
area_list =[ml,db,nlp]

# %% [markdown]
# ## articles wrote by author and related area

# %%
for index, row in NPub[NPub['Papertype'] == 'fullPaper'].iterrows():
    g.add((fullPaper+str(row['article_ID']),RDF.type,fullPaper) )
    g.add((fullPaper+str(row['article_ID']),FOAF.name, Literal(row['title'], datatype=XSD.string)) )
    g.add((fullPaper,relatedto,URIRef(np.random.choice(area_list))))
    g.add((author+str(row['ID_x']),wrote,fullPaper+str(row['article_ID'])))
    
for index, row in NPub[NPub['Papertype'] == 'demoPaper'].iterrows():
    g.add((demoPaper+str(row['article_ID']),RDF.type,demoPaper) )
    g.add((demoPaper+str(row['article_ID']),FOAF.name, Literal(row['title'], datatype=XSD.string)) )
    g.add((demoPaper,relatedto,URIRef(np.random.choice(area_list))))
    g.add((author+str(row['ID_x']),wrote,demoPaper+str(row['article_ID'])))

for index, row in NPub[NPub['Papertype'] == 'shortPaper'].iterrows():
    g.add((shortPaper+str(row['article_ID']),RDF.type,shortPaper) )
    g.add((shortPaper+str(row['article_ID']),FOAF.name, Literal(row['title'], datatype=XSD.string)) )
    g.add((shortPaper,relatedto,URIRef(np.random.choice(area_list))))
    g.add((author+str(row['ID_x']),wrote,shortPaper+str(row['article_ID'])))

for index, row in NPub[NPub['Papertype'] == 'Poster'].iterrows():
    g.add((poster+str(row['article_ID']),RDF.type,poster) )
    g.add((poster+str(row['article_ID']),FOAF.name, Literal(row['title'], datatype=XSD.string)) )
    g.add((poster,relatedto,URIRef(np.random.choice(area_list))))
    g.add((author+str(row['ID_x']),wrote,poster+str(row['article_ID'])))

# %% [markdown]
# ### paper accepted in publication

# %%
for index, row in NPub[NPub['Papertype'] == 'fullPaper'].iterrows():
    g.add((fullPaper+str(row['article_ID']),accepted,Publication+str(row['publisher_ID'])))    
    
    
for index, row in NPub[NPub['Papertype'] == 'demoPaper'].iterrows():
    g.add((demoPaper+str(row['article_ID']),accepted,Publication+str(row['publisher_ID'])))  
   

for index, row in NPub[NPub['Papertype'] == 'shortPaper'].iterrows():
    g.add((shortPaper+str(row['article_ID']),accepted,Publication+str(row['publisher_ID'])))  
   
for index, row in NPub[NPub['Papertype'] == 'Poster'].iterrows():
    g.add((poster+str(row['article_ID']),accepted,Publication+str(row['publisher_ID'])))

# %% [markdown]
# ## conference

# %%
conf = pd.read_csv('kaggle_data_processed/conference.csv')

# %%
conf
# Out:
#       ID                                               name              Type  \
# 0      1      Advances in Intelligent Systems and Computing  Conference Paper
# 1      2            Lecture Notes in Electrical Engineering  Conference Paper
# 2      5                         Telematics and Informatics  Conference Paper
# 3      6                    Electric Power Systems Research  Conference Paper
# 4      7                           Optical Fiber Technology  Conference Paper
# ..   ...                                                ...               ...
# 299  400                          CAD Computer Aided Design  Conference Paper
# 300  401  International Symposium on Advances in Computa...  Conference Paper
# 301  402  AIAA SPACE and Astronautics Forum and Expositi...  Conference Paper
# 302  403    IEEE Transactions on Control of Network Systems  Conference Paper
# 303  404                 Innovations in Dryland Agriculture  Conference Paper
#
#          Conferencetype
# 0             workshops
# 1             workshops
# 2             workshops
# 3             workshops
# 4             workshops
# ..                  ...
# 299  regularConferences
# 300  regularConferences
# 301  regularConferences
# 302  regularConferences
# 303  regularConferences
#
# [304 rows x 4 columns]

# %%
#Conf = NPub[NPub['Type'] == 'Conference Paper']# divide paper into subclasses type
tf = math.ceil(conf.shape[0]*.25)
conf['Conferencetype'] = ''
conf['Conferencetype'].iloc[:tf] = 'workshops'
conf['Conferencetype'].iloc[tf:2*tf] = 'symposiums'
conf['Conferencetype'].iloc[2*tf:3*tf] = 'expertGroups'
conf['Conferencetype'].iloc[3*tf:] = 'regularConferences'
# Out:
# <ipython-input-184-14efe2fe02d1>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   conf['Conferencetype'].iloc[:tf] = 'workshops'
# <ipython-input-184-14efe2fe02d1>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   conf['Conferencetype'].iloc[tf:2*tf] = 'symposiums'
# <ipython-input-184-14efe2fe02d1>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   conf['Conferencetype'].iloc[2*tf:3*tf] = 'expertGroups'
# <ipython-input-184-14efe2fe02d1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   conf['Conferencetype'].iloc[3*tf:] = 'regularConferences'

# %%
for index, row in conf[conf['Conferencetype'] == 'workshops'].iterrows():
    g.add((workshops+str(row['ID']),RDF.type,workshops) )
    g.add((workshops+str(row['ID']),FOAF.name, Literal(row['name'], datatype=XSD.string)) )
    
    
for index, row in conf[conf['Conferencetype'] == 'symposiums'].iterrows():
    g.add((symposiums+str(row['ID']),RDF.type,symposiums) )
    g.add((symposiums+str(row['ID']),FOAF.name, Literal(row['name'], datatype=XSD.string)) )

for index, row in conf[conf['Conferencetype'] == 'expertGroups'].iterrows():
    g.add((expertGrou+str(row['ID']),RDF.type,expertGrou) )
    g.add((expertGrou+str(row['ID']),FOAF.name, Literal(row['name'], datatype=XSD.string)) )

for index, row in conf[conf['Conferencetype'] == 'regularConferences'].iterrows():
    g.add((regularConferences+str(row['ID']),RDF.type,regularConferences) )
    g.add((regularConferences+str(row['ID']),FOAF.name, Literal(row['name'], datatype=XSD.string)) )

# %% [markdown]
# ### paper submitted in conference

# %%
All = pd.merge(NPub[NPub['Type']=='Conference Paper'],conf , how='left', left_on='publisher_ID', right_on='ID')

# %%
for index, row in All_j.loc[(All_j['Papertype'] == 'fullPaper') & (All['Conferencetype'] == 'workshops')].iterrows():
    g.add((fullPaper+str(row['article_ID']),submittedIn,workshops+str(row['ID'])))   
    
for index, row in All_j.loc[(All_j['Papertype'] == 'fullPaper') & (All['Conferencetype'] == 'symposiums')].iterrows():
    g.add((fullPaper+str(row['article_ID']),submittedIn,symposiums+str(row['ID']))) 
    
for index, row in All_j.loc[(All_j['Papertype'] == 'fullPaper') & (All['Conferencetype'] == 'expertGroups')].iterrows():
    g.add((fullPaper+str(row['article_ID']),submittedIn,expertGrou+str(row['ID']))) 
    
for index, row in All_j.loc[(All_j['Papertype'] == 'fullPaper') & (All['Conferencetype'] == 'regularConferences')].iterrows():
    g.add((fullPaper+str(row['article_ID']),submittedIn,regularConferences+str(row['ID']))) 
    

    
for index, row in All_j.loc[(All_j['Papertype'] == 'demoPaper') & (All['Conferencetype'] == 'workshops')].iterrows():
    g.add((demoPaper+str(row['article_ID']),submittedIn,workshops+str(row['ID'])))   
    
for index, row in All_j.loc[(All_j['Papertype'] == 'demoPaper') & (All['Conferencetype'] == 'symposiums')].iterrows():
    g.add((demoPaper+str(row['article_ID']),submittedIn,symposiums+str(row['ID']))) 
    
for index, row in All_j.loc[(All_j['Papertype'] == 'demoPaper') & (All['Conferencetype'] == 'expertGroups')].iterrows():
    g.add((demoPaper+str(row['article_ID']),submittedIn,expertGrou+str(row['ID']))) 
    
for index, row in All_j.loc[(All_j['Papertype'] == 'demoPaper') & (All['Conferencetype'] == 'regularConferences')].iterrows():
    g.add((demoPaper+str(row['article_ID']),submittedIn,regularConferences+str(row['ID'])))
    
    
    
for index, row in All_j.loc[(All_j['Papertype'] == 'shortPaper') & (All['Conferencetype'] == 'workshops')].iterrows():
    g.add((shortPaper+str(row['article_ID']),submittedIn,workshops+str(row['ID'])))   
    
for index, row in All_j.loc[(All_j['Papertype'] == 'shortPaper') & (All['Conferencetype'] == 'symposiums')].iterrows():
    g.add((shortPaper+str(row['article_ID']),submittedIn,symposiums+str(row['ID']))) 
    
for index, row in All_j.loc[(All_j['Papertype'] == 'shortPaper') & (All['Conferencetype'] == 'expertGroups')].iterrows():
    g.add((shortPaper+str(row['article_ID']),submittedIn,expertGrou+str(row['ID']))) 
    
for index, row in All_j.loc[(All_j['Papertype'] == 'shortPaper') & (All['Conferencetype'] == 'regularConferences')].iterrows():
    g.add((shortPaper+str(row['article_ID']),submittedIn,regularConferences+str(row['ID']))) 
    


for index, row in All_j.loc[(All_j['Papertype'] == 'Poster') & (All['Conferencetype'] == 'workshops')].iterrows():
    g.add((poster+str(row['article_ID']),submittedIn,workshops+str(row['ID'])))   
    
for index, row in All_j.loc[(All_j['Papertype'] == 'Poster') & (All['Conferencetype'] == 'symposiums')].iterrows():
    g.add((poster+str(row['article_ID']),submittedIn,symposiums+str(row['ID']))) 
    
for index, row in All_j.loc[(All_j['Papertype'] == 'Poster') & (All['Conferencetype'] == 'expertGroups')].iterrows():
    g.add((poster+str(row['article_ID']),submittedIn,expertGrou+str(row['ID']))) 
    
for index, row in All_j.loc[(All_j['Papertype'] == 'Poster') & (All['Conferencetype'] == 'regularConferences')].iterrows():
    g.add((poster+str(row['article_ID']),submittedIn,regularConferences+str(row['ID'])))

# %% [markdown]
# ## journals

# %%
jour = pd.read_csv('kaggle_data_processed/journal.csv')

# %%
journal
# Out:
# rdflib.term.URIRef('http://exampleDb.org/journal')

# %%
for index, row in jour.iterrows():
    g.add((journal+str(row['ID']),RDF.type,journal))
    g.add((journal+str(row['ID']),FOAF.name, Literal(row['name'], datatype=XSD.string)))

# %% [markdown]
# ### submitted In journals

# %%
All_j = pd.merge(NPub[NPub['Type']=='Journal'],jour , how='left', left_on='publisher_ID', right_on='ID')

# %%
for index, row in All_j[All_j['Papertype'] == 'fullPaper'].iterrows():
    g.add((fullPaper+str(row['article_ID']),submittedIn,journal+str(row['ID'])))    
    
    
for index, row in All_j[All_j['Papertype'] == 'demoPaper'].iterrows():
    g.add((demoPaper+str(row['article_ID']),submittedIn,journal+str(row['ID'])))  
   

for index, row in All_j[All_j['Papertype'] == 'shortPaper'].iterrows():
    g.add((shortPaper+str(row['article_ID']),submittedIn,journal+str(row['ID'])))  
   
for index, row in All_j[All_j['Papertype'] == 'Poster'].iterrows():
    g.add((poster+str(row['article_ID']),submittedIn,journal+str(row['ID'])))

# %% [markdown]
# ### reviews

# %%
reviews_df['paper_id'] = NPub['article_ID']

# %%
reviews_df['paper_id']
# Out:
# 0       298
# 1       626
# 2       626
# 3       157
# 4       175
#        ...
# 5315    443
# 5316    443
# 5317    443
# 5318    799
# 5319    799
# Name: paper_id, Length: 5320, dtype: int64

# %%
reviews_df['paper_id'].append(NPub['article_ID'])
# Out:
# <ipython-input-284-3971b1a5d480>:1: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reviews_df['paper_id'].append(NPub['article_ID'])
# 0       298
# 1       626
# 2       626
# 3       157
# 4       175
#        ...
# 5315    443
# 5316    443
# 5317    443
# 5318    799
# 5319    799
# Length: 10640, dtype: int64

# %%
comment = ['good','ok','perfecto']
reviews_df = pd.DataFrame(columns=['Reviewer_ID','paper_id','decision','comments'])
reviews_df['paper_id'] = NPub['article_ID'] 
reviews_df['Reviewer_ID']=np.random.choice(review_twenty['ID'], size=len(reviews_df))
reviews_df['decision'] = 1
reviews_df['comments'] = np.random.choice(comment, size=len(reviews_df))

# %%
NPub['article_ID'].value_counts()
# Out:
# 247    36
# 134    36
# 44     36
# 147    36
# 443    36
#        ..
# 821     1
# 644     1
# 829     1
# 790     1
# 697     1
# Name: article_ID, Length: 674, dtype: int64

# %%
review_twenty['ID']
# Out:
# 1304     7005486887
# 1305    34874038200
# 1306    57201366662
# 1307    57201358872
# 1308     7202006620
#            ...
# 1733    55628341300
# 1734    57201125120
# 1735    47461179000
# 1736    25930868900
# 1737    57194639611
# Name: ID, Length: 434, dtype: int64

# %%
NPub
# Out:
#              ID_x         name_x  article_ID  \
# 0      7004904337  Crandall J.W.         298
# 1      7004904337  Crandall J.W.         626
# 2      7004904337  Crandall J.W.         626
# 3      7005513246  Goodrich M.A.         157
# 4      7005513246  Goodrich M.A.         175
# ...           ...            ...         ...
# 5315  56701050600  Reynolds P.R.         443
# 5316  56701050600  Reynolds P.R.         443
# 5317  56701050600  Reynolds P.R.         443
# 5318  56701050600  Reynolds P.R.         799
# 5319  56701050600  Reynolds P.R.         799
#
#                                                   title  Papertype  \
# 0     Cooperating in long-term relationships with ti...  fullPaper
# 1     Information design in crowdfunding under thres...  fullPaper
# 2     Information design in crowdfunding under thres...  fullPaper
# 3     Intent-based robotic path-replanning: When to ...  fullPaper
# 4     Transparency: Transitioning From Human–Machine...  fullPaper
# ...                                                 ...        ...
# 5315  Corrigendum: Efficient decellularization of wh...     Poster
# 5316  Corrigendum: Efficient decellularization of wh...     Poster
# 5317  Corrigendum: Efficient decellularization of wh...     Poster
# 5318  Re-epithelialization of whole porcine kidneys ...     Poster
# 5319  Re-epithelialization of whole porcine kidneys ...     Poster
#
#       publisher_ID  year                                             name_y  \
# 0              247  2017       Theoretical and Computational Fluid Dynamics
# 1              313  2017  2018 Aviation Technology, Integration, and Ope...
# 2              253  2018  2018 IEEE 3rd International Verification and S...
# 3              390  2019  IGLC 2017 - Proceedings of the 25th Annual Con...
# 4               18  2017                        Applied Thermal Engineering
# ...            ...   ...                                                ...
# 5315            16  2017               Journal of Nondestructive Evaluation
# 5316           347  2017  Journal of Traffic and Transportation Engineer...
# 5317           273  2017        Handbook of Thermal Science and Engineering
# 5318           182  2016  Proceedings of the IEEE Conference on Decision...
# 5319           350  2017                    Journal of Technology Education
#
#                   Type
# 0     Conference Paper
# 1     Conference Paper
# 2     Conference Paper
# 3     Conference Paper
# 4     Conference Paper
# ...                ...
# 5315           Journal
# 5316           Journal
# 5317  Conference Paper
# 5318  Conference Paper
# 5319           Journal
#
# [5320 rows x 9 columns]

# %%
symb = pd.DataFrame(['a', 'b', 'c'], columns=['symb'])
fld = pd.DataFrame(['field1', 'field2', 'field3'], columns=['fld'])
symb['one'] = 1
fld['one'] = 1
print(pd.merge(symb, fld, on='one').drop('one', axis=1))
# Out:
#   symb     fld
# 0    a  field1
# 1    a  field2
# 2    a  field3
# 3    b  field1
# 4    b  field2
# 5    b  field3
# 6    c  field1
# 7    c  field2
# 8    c  field3
